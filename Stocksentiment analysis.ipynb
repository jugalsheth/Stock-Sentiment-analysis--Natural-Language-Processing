# %%
import pandas as pd

# %%
data = pd.read_csv('Data.csv',encoding = "ISO-8859-1")

# %%
data.head(2)
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
#
#                   Top2                             Top3  \
# 0            Scorecard  Hughes' instant hit buoys Blues
# 1  The best lake scene    Leader: German sleaze inquiry
#
#                                        Top4  \
# 0  Jack gets his skates on at ice-cold Alex
# 1                             Cheerio, boyo
#
#                                      Top5  \
# 0  Chaos as Maracana builds up for United
# 1                The main recommendations
#
#                                                 Top6  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees?
#
#                                Top7                               Top8  ...  \
# ...

# %%
train = data[data['Date'] < '20150101']
test = data[data['Date'] > '20141231']

# %%
traindf = train.iloc[:,2:27]
traindf.replace('[^a-zA-Z]',' ', regex = True, inplace = True)

list1 = [i for i in range(25)]
new_list = [str(i)for i in list1]
traindf.columns = new_list

# %%
traindf.head(2)
# Out:
#                                                    0                    1  \
# 0  A  hindrance to operations   extracts from the...            Scorecard
# 1                                          Scorecard  The best lake scene
#
#                                  2                                         3  \
# 0  Hughes  instant hit buoys Blues  Jack gets his skates on at ice cold Alex
# 1    Leader  German sleaze inquiry                             Cheerio  boyo
#
#                                         4  \
# 0  Chaos as Maracana builds up for United
# 1                The main recommendations
#
#                                                    5  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees
#
#                                   6                                  7  \
# 0  Hungry Spurs sense rich pickings  Gunners so wide of an easy target
# ...

# %%
for i in new_list:
    traindf[i] = traindf[i].str.lower()
traindf.head(2)
# Out:
#                                                    0                    1  \
# 0  a  hindrance to operations   extracts from the...            scorecard
# 1                                          scorecard  the best lake scene
#
#                                  2                                         3  \
# 0  hughes  instant hit buoys blues  jack gets his skates on at ice cold alex
# 1    leader  german sleaze inquiry                             cheerio  boyo
#
#                                         4  \
# 0  chaos as maracana builds up for united
# 1                the main recommendations
#
#                                                    5  \
# 0  depleted leicester prevail as elliott spoils e...
# 1                             has cubie killed fees
#
#                                   6                                  7  \
# 0  hungry spurs sense rich pickings  gunners so wide of an easy target
# ...

# %%
headline = []
for row in range(0,len(traindf.index)):
    headline.append(' '.join(str(x) for x in traindf.iloc[row,0:25]))

# %%
#headline

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(2,2))
trainingdataset = cv.fit_transform(headline)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200,criterion='entropy')
rfc.fit(trainingdataset,train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
test_transformer = []
for row in range(0,len(test.index)):
    test_transformer.append(' '.join(str(x) for x in test.iloc[row,2:27]))

test_data = cv.transform(test_transformer)
pred = rfc.predict(test_data)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(test['Label'],pred)
accuracy
# Out:
# 0.8518518518518519

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test['Label'],pred)
cm
# Out:
# array([[138,  48],
#        [  8, 184]], dtype=int64)

# %%
from sklearn.metrics import classification_report
report = classification_report(test['Label'],pred)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.95      0.74      0.83       186\n           1       0.79      0.96      0.87       192\n\n    accuracy                           0.85       378\n   macro avg       0.87      0.85      0.85       378\nweighted avg       0.87      0.85      0.85       378\n'
